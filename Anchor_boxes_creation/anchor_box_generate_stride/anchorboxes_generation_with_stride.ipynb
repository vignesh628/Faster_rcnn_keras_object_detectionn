# %%
import math
anchor_sizes=[64, 128, 256]
anchor_ratios=[[1, 1], [0.7071067811865475, 1.414213562373095], [1.414213562373095, 0.7071067811865475]]
output_width=18
output_height=25
downscale=16
#image size that we have is 300,400
for anchor_size_idx in range(len(anchor_sizes)):
    for anchor_ratio_idx in range(len(anchor_ratios)):
        anchor_x = anchor_sizes[anchor_size_idx] * anchor_ratios[anchor_ratio_idx][0]
        anchor_y = anchor_sizes[anchor_size_idx] * anchor_ratios[anchor_ratio_idx][1]
        print('*****************************************************************')
        print(anchor_x)
        print(anchor_y)
        for ix in range(output_width):					
            # x-coordinates of the current anchor box	
            x1_anc = downscale * (ix + 0.5) - anchor_x / 2
            x2_anc = downscale * (ix + 0.5) + anchor_x / 2
            for iy in range(output_height):
                y1_anc=downscale * (iy + 0.5) - anchor_y / 2
                y2_anc = downscale * (iy + 0.5) + anchor_y / 2
            print('my final anchor box coordinates are ',x1_anc,x2_anc,y1_anc,y2_anc)
            print('If you see here x and y coordinates are',(x2_anc-x1_anc),(y2_anc-y1_anc))
# Out:
# *****************************************************************
# 64
# 64
# my final anchor box coordinates are  -24.0 40.0 360.0 424.0
# If you see here x and y coordinates are 64.0 64.0
# my final anchor box coordinates are  -8.0 56.0 360.0 424.0
# If you see here x and y coordinates are 64.0 64.0
# my final anchor box coordinates are  8.0 72.0 360.0 424.0
# If you see here x and y coordinates are 64.0 64.0
# my final anchor box coordinates are  24.0 88.0 360.0 424.0
# If you see here x and y coordinates are 64.0 64.0
# my final anchor box coordinates are  40.0 104.0 360.0 424.0
# If you see here x and y coordinates are 64.0 64.0
# my final anchor box coordinates are  56.0 120.0 360.0 424.0
# If you see here x and y coordinates are 64.0 64.0
# my final anchor box coordinates are  72.0 136.0 360.0 424.0
# If you see here x and y coordinates are 64.0 64.0
# my final anchor box coordinates are  88.0 152.0 360.0 424.0
# If you see here x and y coordinates are 64.0 64.0
# ...

# %%
import math
anchor_sizes=[64, 128, 256]
anchor_ratios=[[1, 1], [0.7071067811865475, 1.414213562373095], [1.414213562373095, 0.7071067811865475]]
output_width=18
output_height=25
downscale=16
#image size that we have is 300,400
for anchor_size_idx in range(len(anchor_sizes)):
    for anchor_ratio_idx in range(len(anchor_ratios)):
        anchor_x = anchor_sizes[anchor_size_idx] * anchor_ratios[anchor_ratio_idx][0]
        anchor_y = anchor_sizes[anchor_size_idx] * anchor_ratios[anchor_ratio_idx][1]
        print('*****************************************************************')
        print(anchor_x)
        print(anchor_y)
        for ix in range(output_width):					
            # x-coordinates of the current anchor box	
            x1_anc =  (ix + 0.5) - anchor_x / 2
            x2_anc = (ix + 0.5) + anchor_x / 2
            for iy in range(output_height):
                y1_anc= (iy + 0.5) - anchor_y / 2
                y2_anc = (iy + 0.5) + anchor_y / 2
            print('my final anchor box coordinates are ',x1_anc,x2_anc,y1_anc,y2_anc)
            print('If you see here x and y coordinates are',(x2_anc-x1_anc),(y2_anc-y1_anc))
# Out:
# *****************************************************************
# 64
# 64
# my final anchor box coordinates are  -31.5 32.5 -7.5 56.5
# If you see here x and y coordinates are 64.0 64.0
# my final anchor box coordinates are  -30.5 33.5 -7.5 56.5
# If you see here x and y coordinates are 64.0 64.0
# my final anchor box coordinates are  -29.5 34.5 -7.5 56.5
# If you see here x and y coordinates are 64.0 64.0
# my final anchor box coordinates are  -28.5 35.5 -7.5 56.5
# If you see here x and y coordinates are 64.0 64.0
# my final anchor box coordinates are  -27.5 36.5 -7.5 56.5
# If you see here x and y coordinates are 64.0 64.0
# my final anchor box coordinates are  -26.5 37.5 -7.5 56.5
# If you see here x and y coordinates are 64.0 64.0
# my final anchor box coordinates are  -25.5 38.5 -7.5 56.5
# If you see here x and y coordinates are 64.0 64.0
# my final anchor box coordinates are  -24.5 39.5 -7.5 56.5
# If you see here x and y coordinates are 64.0 64.0
# ...

# %% [markdown]
# * Difference between both of the cells is we are getting the anchor boxes at vaious positions.
